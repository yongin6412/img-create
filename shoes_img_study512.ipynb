# %% [markdown]
# <a href="https://colab.research.google.com/github/yongin6412/test1/blob/master/shoes_img_study512.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# function ClickConnect(){ console.log("코랩 연결 끊김 방지"); document.querySelector("colab-toolbar-button#connect").click() } setInterval(ClickConnect, 60 * 1000)

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-7f1e401f-e2bc-fd3e-a9ce-a4f15978b75d)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

# %%
torch.cuda.device_count() #GPU연결이 되야함 1로 표시되야한다
# Out:
# 1

# %%
import torchvision

# %%
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.9/205.9 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 65.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.4.8
#     Uninstalling imageio-ffmpeg-0.4.8:
#       Successfully uninstalled imageio-ffmpeg-0.4.8
# ...

# %%
# !python --version
# Out:
# Python 3.10.11

# %%
# !wget https://www.python.org/ftp/python/3.6.9/Python-3.6.9.tgz
# !tar xvfz Python-3.6.9.tgz
# !Python-3.6.9/configure
# !make
# !sudo make install
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_2.py'...
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_3.py'...
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_4.py'...
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_5.py'...
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_6.py'...
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_7.py'...
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_8.py'...
# Compiling '/usr/local/lib/python3.6/encodings/iso8859_9.py'...
# Compiling '/usr/local/lib/python3.6/encodings/johab.py'...
# Compiling '/usr/local/lib/python3.6/encodings/koi8_r.py'...
# Compiling '/usr/local/lib/python3.6/encodings/koi8_t.py'...
# Compiling '/usr/local/lib/python3.6/encodings/koi8_u.py'...
# Compiling '/usr/local/lib/python3.6/encodings/kz1048.py'...
# Compiling '/usr/local/lib/python3.6/encodings/latin_1.py'...
# Compiling '/usr/local/lib/python3.6/encodings/mac_arabic.py'...
# ...

# %%
# !python --version
# Out:
# Python 3.6.9

# %%
# !pip install torch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2 #파이토치 버전변경
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#     100% |████████████████████████████████| 776.8MB 27kB/s
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/torchvision/
# ...
#     100% |████████████████████████████████| 12.8MB 3.7MB/s
# ...
#     100% |████████████████████████████████| 7.6MB 8.4MB/s
# ...
#     100% |████████████████████████████████| 13.4MB 4.7MB/s
# ...
#     100% |████████████████████████████████| 49.4MB 1.0MB/s
# ...
#   Running setup.py install for pillow ... done
# ...

# %%
pip install click
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#     100% |████████████████████████████████| 102kB 5.9MB/s
# ...

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#     100% |████████████████████████████████| 71kB 4.7MB/s
# ...
#     100% |████████████████████████████████| 163kB 10.6MB/s
# ...
#     100% |████████████████████████████████| 71kB 31.2MB/s
# ...
#     100% |████████████████████████████████| 143kB 39.7MB/s
# ...

# %%
pip install psutil
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#     100% |████████████████████████████████| 501kB 27.6MB/s
#   Installing build dependencies ... done
# ...
#   Running setup.py install for psutil ... done
# ...

# %%
pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#     100% |████████████████████████████████| 25.9MB 714kB/s
# ...

# %%
pip install setuptools --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://files.pythonhosted.org/packages/b0/3a/88b210db68e56854d0bcf4b38e165e03be377e13907746f825790f3df5bf/setuptools-59.6.0-py3-none-any.whl
# ...
#   Found existing installation: setuptools 40.6.2
#     Uninstalling setuptools-40.6.2:
#       Successfully uninstalled setuptools-40.6.2
# ...

# %%
pip install tensorboard
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#     100% |████████████████████████████████| 5.9MB 7.4MB/s
# ...
#   Using cached https://files.pythonhosted.org/packages/27/d6/003e593296a85fd6ed616ed962795b2f87709c3eee2bca4f6d0fe55c6d00/wheel-0.37.1-py2.py3-none-any.whl
# ...
#     100% |████████████████████████████████| 102kB 22.8MB/s
# ...
#     100% |████████████████████████████████| 163kB 38.7MB/s
# ...
#     100% |████████████████████████████████| 184kB 40.6MB/s
# ...
#     100% |████████████████████████████████| 133kB 42.8MB/s
# ...
#     100% |████████████████████████████████| 296kB 22.2MB/s
# ...
#     100% |████████████████████████████████| 788kB 21.3MB/s
# ...
#     100% |████████████████████████████████| 22.0MB 602kB/s
# ...
#     100% |████████████████████████████████| 184kB 26.0MB/s
# ...
#     100% |████████████████████████████████| 153kB 29.0MB/s
# ...
#     100% |████████████████████████████████| 92kB 25.4MB/s
# ...
#   Running setup.py install for grpcio ... done
# ...

# %%
cd /content/drive/MyDrive/Colab_Notebooks/shoes/stylegan2-ada-pytorch
# Out:
# /content/drive/MyDrive/Colab_Notebooks/shoes/stylegan2-ada-pytorch

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab_Notebooks/shoes/stylegan2-ada-pytorch'

# %% [markdown]
# # **트레이닝모델**

# %%
# !python train.py --outdir=/content/drive/MyDrive/shoes_result_512/shoes512_1 --data=./datasets512/shoesdata512.zip --gpus=1 --augpipe=bg --gamma=10 --cfg=paper512 --mirror=1 --snap=10 --metrics=none
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets512/shoesdata512.zip",
#     "use_labels": false,
#     "max_size": 3237,
#     "xflip": true,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %% [markdown]
# # **이어서 학습시키기**
# 80pkl

# %%
# !python train.py --resume /content/drive/MyDrive/shoes_result_512/shoes512_1/00000-shoesdata512-mirror-paper512-gamma10-bg/network-snapshot-000080.pkl --outdir=/content/drive/MyDrive/shoes_result_512/shoes512_2 --data=./datasets512/shoesdata512.zip --gpus=1 --augpipe=bg --gamma=10 --cfg=paper512 --mirror=1 --snap=10 --metrics=none
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets512/shoesdata512.zip",
#     "use_labels": false,
#     "max_size": 3237,
#     "xflip": true,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %% [markdown]
# # **160pkl 이어서 학습**

# %%
# !python train.py --resume /content/drive/MyDrive/shoes_result_512/shoes512_2/00000-shoesdata512-mirror-paper512-gamma10-bg-resumecustom/network-snapshot-000160.pkl --outdir=/content/drive/MyDrive/shoes_result_512/shoes512_2 --data=./datasets512/shoesdata512.zip --gpus=1 --augpipe=bg --gamma=10 --cfg=paper512 --mirror=1 --snap=10 --metrics=none
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets512/shoesdata512.zip",
#     "use_labels": false,
#     "max_size": 3237,
#     "xflip": true,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %% [markdown]
# # **280pkl 이어서 학습**

# %%
# !python train.py --resume /content/drive/MyDrive/shoes_result_512/shoes512_2/00001-shoesdata512-mirror-paper512-gamma10-bg-resumecustom/network-snapshot-000281.pkl --outdir=/content/drive/MyDrive/shoes_result_512/shoes512_2 --data=./datasets512/shoesdata512.zip --gpus=1 --augpipe=bg --gamma=10 --cfg=paper512 --mirror=1 --snap=10 --metrics=none
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets512/shoesdata512.zip",
#     "use_labels": false,
#     "max_size": 3237,
#     "xflip": true,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...
